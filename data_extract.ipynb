# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time

# %%
# The URL of the web page for scrape 534 city name
url = "https://aqicn.org/city/all/"

# Send a GET request to the website
response = requests.get(url)

# %%
# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find the container that holds the city names
container = soup.find("div", class_="main-cities")

# Find all <a> elements, which contain the city names
city_elements = container.find_all("a")

# Extract the city names from the <a> elements and strip leading/trailing whitespace
cities = [city_element.text.strip() for city_element in city_elements]

# Create a DataFrame to hold the city names
cities_df = pd.DataFrame(cities, columns=["City Name"])
cities_df
# Out:
#                  City Name
# 0            Shanghai (上海)
# 1             Beijing (北京)
# 2             Tianjin (天津)
# 3          Guangzhou (广州市)
# 4            Shenzhen (深圳)
# ..                     ...
# 528  Addis Ababa (አዲስ አበባ)
# 529                Nairobi
# 530      Kampala (كامبالا)
# 531      Algiers (الجزائر)
# 532        Bamako (Bamakɔ)
#
# [533 rows x 1 columns]

# %%
# Clean the City Name
cities_df['City Name'] = cities_df['City Name'].str.replace(r'\s+\(.*\)', '', regex=True)
cities_df
# Out:
#        City Name
# 0       Shanghai
# 1        Beijing
# 2        Tianjin
# 3      Guangzhou
# 4       Shenzhen
# ..           ...
# 528  Addis Ababa
# 529      Nairobi
# 530      Kampala
# 531      Algiers
# 532       Bamako
#
# [533 rows x 1 columns]

# %%
# Convert 534 cities to the list
cities_list = cities_df["City Name"].tolist()
print(cities_list)
# Out:
# ['Shanghai', 'Beijing', 'Tianjin', 'Guangzhou', 'Shenzhen', 'Wuhan', 'Dongguan', 'Chongqing', 'Chengdu', 'Nanjing', 'Taipei', 'Kaohsiung', 'Taichung', 'tainan', 'banqiao', 'hsinchu', 'taoyuan-city', 'Keelung', 'Hong Kong', 'Macao', 'Hanyang', 'Busan', 'Incheon', 'Daejeon', 'Ulsan', 'Daegu', 'Gwangju', 'Suwon', 'Goyang', 'Seongnam', 'Edo', 'Yokohama', 'Osaka', 'Nagoya', 'Sapporo', 'Kobe', 'Kyoto', 'Fukuoka', 'Kawasaki', 'saitama', 'Moscow', 'Krasnoyarsk', 'Kaliningrad', 'Leningrad', 'Novo-Nikolaevsk', 'Nizhniy Novgorod', 'Chelyabinsk', 'Ufa', 'Dhaka', 'Kathmandu', 'Pokhara', 'Patan', 'biratnagar', 'Birgunj', 'dharan-bazar', 'Bharatpur', 'Bombay', 'Delhi', 'Bangalore', 'Calcutta', 'Chennai', 'Ahmedabad', 'Hyderabad', 'Pune', 'Kanpur', 'Bangkok', 'mueang-samut-prakan', 'Nonthaburi', 'chon-buri', 'Nakhon Ratchasima', 'Chiangmai', 'Hat Yai', 'Pak Kret', 'si-racha', 'Amphoe Phra Pradaeng', 'Lampang', 'surin', 'Vientiane', 'Rangoon', 'Kota Bharu', 'Kuala Lumpur', 'klang', 'kampung-baru-subang', 'Johor Bahru', 'Subang Jaya', 'Ipoh', 'Kuching', 'Ho Chi Minh City', 'Hanoi', 'Da Nang', 'Haiphong', 'bien-hoa', 'Huế', 'Nha Trang', 'Bandar Seri Begawan', 'City of Manila', 'Jakarta', 'Medan', 'Bekasi', 'Palembang', 'Tangerang', 'south-tangerang', 'Colombo', 'galkissa', 'moratuwa', 'Negombo', 'pita-kotte', 'Kotte', 'Astana', 'Almaty', 'Dushanbe', 'vahdat', 'tursunzoda', 'Bishkek', 'Tashkent', 'Phnom Penh', 'Montreal', 'Toronto', 'Vancouver', 'Calgary', 'Ottawa', 'Edmonton', 'Mississauga', 'north-york', 'Winnipeg', 'scarborough', 'Auckland', 'Wellington', 'Christchurch', 'Manukau', 'waitakere', 'North Shore', 'Hamilton', 'Dunedin', 'Lower Hutt', 'Syd', 'Melbourne', 'Brisbane', 'Perth', 'Adelaide', 'Gold', 'Canberra', 'Newcastle', 'Wollongong', 'Logan', 'Big Apple', 'Big Apple', 'LA', 'Chicago', 'Borough of Brooklyn', 'borough-of-queens', 'houston', 'Philadelphia', 'manhattan', 'Phoenix', 'Borough of Bronx', 'Lima', 'Callao', 'laventille', 'Santiago', 'puente-alto', 'Antofagasta', 'Viña del Mar', 'Valparaíso', 'Talcahuano', 'san-bernardo', 'temuco', 'Iquique', 'Concepción', 'São Paulo', 'Mexico City', 'iztapalapa', 'Ecatepec de Morelos', 'Guadalajara', 'Puebla', 'Ciudad Juárez', 'Tijuana', 'Ciudad Neza', 'Bogotá', 'Santiago de Cali', 'Medellín', 'Willemstad', 'sint-michiel-liber', 'barber', 'dorp-soto', 'newport', 'sabana-westpunt', 'dorp-sint-willebrordus', 'lagun', 'Quito', 'Cuenca', 'Buenos Aires', 'San Salvador', 'San Juan', 'Guatemala City', 'San José', 'Paris', 'Marseille', 'Lyon', 'Toulouse', 'Nice', 'Nantes', 'Strasbourg', 'Montpellier', 'Bordeaux', 'Lille', 'Tallinn', 'Tartu', 'Narva', 'Kohtla-Järve', 'rakvere', 'Sillamäe', 'Maardu', 'Kuressaare', 'Madrid', 'Barcelona', 'Valencia', 'Seville', 'Saragossa', 'Málaga', 'Murcia', 'Palma de Mallorca', 'Las Palmas de Gran Canaria', 'bilbao', 'City of London', 'city-of-london', 'Zurich', 'Geneva', 'Basel', 'Bern', 'Lausanne', 'Winterthur', 'St. Gallen', 'Lucerne', 'Prague', 'Brno', 'Ostrava', 'Pilsen', 'Olomouc', 'Liberec', 'Budweis', 'Hradec Králové', 'Rome', 'Milan', 'Naples', 'Turin', 'Genoa', 'Bologna', 'Florence', 'Bratislava', 'Košice', 'Prešov', 'Nitra', 'Žilina', 'Banská Bystrica', 'Trnava', 'martin', 'Oslo', 'Bergen', 'Trondheim', 'Stavanger', 'Drammen', 'Fredrikstad', 'Kristiansand', 'Sandnes', 'Vienna', 'Graz', 'Linz', 'Salzburg', 'Innsbruck', 'Klagenfurt', 'Villach', 'Wels', 'Nicosia', 'Limassol', 'Larnaca', 'Famagusta', 'Paphos', 'Keryneia', 'Protaras', 'pergamos', 'Warsaw', 'Łódź', 'Krakow', 'Wrocław', 'poznan', 'Gdańsk', 'Szczecin', 'Bydgoszcz', 'Lublin', 'Katowice', 'Brussels', 'Antwerp', 'Ghent', 'Charleroi', 'Liège', 'Bruges', 'Namur', 'Leuven', 'Amsterdam', 'Rotterdam', 'Hague', 'Utrecht', 'Eindhoven', 'Tilburg', 'Groningen', 'Almere', 'Breda', 'Nijmegen', 'Copenhagen', 'frederiksberg', 'Vilnius', 'Kaunas', 'Klaipėda', 'Šiauliai', 'dainava-kaunas', 'eiguliai', 'Budapest', 'Debrecen', 'Miskolc', 'szeged', 'Pécs', 'budapest-xi.-kerulet', 'budapest-iii.-kerulet', 'budapest-xiv. ...

# %%
# The beginning and end parts of the URL to access the API for each city
base_url_cities_0 = "http://api.waqi.info/feed/"
base_url_cities_1 = "/?token=cfec51e63370e90b7880950705e8add14a2602b6"

# Define an empty dictionary to store the results
results = {}

# For each city in the list, send a GET request to the API and store the response in the dictionary
for city in cities_list:
    try:
        base_url_cities = base_url_cities_0 + city + base_url_cities_1
        response_cities = requests.get(base_url_cities)
        
        # Raise an exception if the request was unsuccessful
        response_cities.raise_for_status()
        
        # Store the JSON response in the dictionary
        results[city] = response_cities.json()
        
        # Wait for 1 second before sending the next request, to avoid overloading the server
        time.sleep(1)
    except requests.exceptions.HTTPError as err:
        # Print an error message if a city's data could not be retrieved
        print(f"HTTP error occurred for {city}: {err}")

# Save the results to a JSON file
with open("aqi_data_indent1.json", "w") as json_file:
    json.dump(results, json_file, indent=1)

# %%
# Load the JSON file if it is correct
with open('aqi_data_indent1.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'Shanghai': {'status': 'ok',
#   'data': {'aqi': 80,
#    'idx': 1437,
#    'attributions': [{'url': 'https://china.usembassy-china.org.cn/embassy-consulates/shanghai/air-quality-monitor-stateair/',
#      'name': 'U.S. Consulate Shanghai Air Quality Monitor'},
#     {'url': 'https://sthj.sh.gov.cn/',
#      'name': 'Shanghai Environment Monitoring Center(上海市环境监测中心)'},
#     {'url': 'http://106.37.208.233:20035/emcpublish/',
#      'name': 'China National Urban air quality real-time publishing platform (全国城市空气质量实时发布平台)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [31.2047372, 121.4489017],
#     'name': 'Shanghai (上海)',
#     'url': 'https://aqicn.org/city/shanghai',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 6.8},
#     'h': {'v': 94},
#     'no2': {'v': 17},
#     'o3': {'v': 20.4},
#     'p': {'v': 1013},
#     'pm10': {'v': 38},
#     'pm25': {'v': 80},
#     'so2': {'v': 3.6},
#     't': {'v': 23},
#     'w': {'v': 1.5}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 1,
#        'day': '2023-05-24',
#        'max': 3,
#        'min': 1},
#       {'avg': 1, 'day': '2023-05-25', 'max': 6, 'min': 1},
#       {'avg': 1, 'day': '2023-05-26', 'max': 6, 'min': 1},
#       {'avg': 3, 'day': '2023-05-27', 'max': 13, 'min': 1},
#       {'avg': 3, 'day': '2023-05-28', 'max': 19, 'min': 1},
#       {'avg': 1, 'day': '2023-05-29', 'max': 6, 'min': 1},
#       {'avg': 1, 'day': '2023-05-30', 'max': 3, 'min': 1},
#       {'avg': 3, 'day': '2023-05-31', 'max': 4, 'min': 3}],
#      'pm10': [{'avg': 60, 'day': '2023-05-25', 'max': 76, 'min': 46},
#       {'avg': 92, 'day': '2023-05-26', 'max': 126, 'min': 46},
#       {'avg': 59, 'day': '2023-05-27', 'max': 76, 'min': 46},
#       {'avg': 52, 'day': '2023-05-28', 'max': 58, 'min': 46},
#       {'avg': 82, 'day': '2023-05-29', 'max': 172, 'min': 28},
#       {'avg': 94, 'day': '2023-05-30', 'max': 168, 'min': 29},
#       {'avg': 154, 'day': '2023-05-31', 'max': 396, 'min': 42},
#       {'avg': 73, 'day': '2023-06-01', 'max': 123, 'min': 19}],
#      'pm25': [{'avg': 150, 'day': '2023-05-25', 'max': 162, 'min': 138},
#       {'avg': 201, 'day': '2023-05-26', 'max': 252, 'min': 138},
#       {'avg': 129, 'day': '2023-05-27', 'max': 177, 'min': 69},
#       {'avg': 126, 'day': '2023-05-28', 'max': 141, 'min': 85},
#       {'avg': 162, 'day': '2023-05-29', 'max': 252, 'min': 71},
#       {'avg': 177, 'day': '2023-05-30', 'max': 252, 'min': 85},
#       {'avg': 182, 'day': '2023-05-31', 'max': 252, 'min': 85},
#       {'avg': 140, 'day': '2023-06-01', 'max': 252, 'min': 68}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T01:28:46+09:00'}}},
#  'Beijing': {'status': 'ok',
#   'data': {'aqi': 112,
#    'idx': 1451,
#    'attributions': [{'url': 'http://www.bjmemc.com.cn/',
#      'name': 'Beijing Environmental Protection Monitoring Center (北京市环境保护监测中心)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [39.954592, 116.468117],
#     'name': 'Beijing (北京)',
#     'url': 'https://aqicn.org/city/beijing',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 5.5},
#     'h': {'v': 70.5},
#     'no2': {'v': 8.7},
#     'o3': {'v': 44.3},
#     'p': {'v': 1012},
#     'pm10': {'v': 64},
#     'pm25': {'v': 112},
#     'so2': {'v': 0.6},
#     't': {'v': 22},
#     'w': {'v': 2.5}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 20,
#        'day': '2023-05-25',
#        'max': 35,
#        'min': 11},
#       {'avg': 16, 'day': '2023-05-26', 'max': 45, 'min': 1},
#       {'avg': 6, 'day': '2023-05-27', 'max': 13, 'min': 1},
#       {'avg': 10, 'day': '2023-05-28', 'max': 50, 'min': 1},
#       {'avg': 9, 'day': '2023-05-29', 'max': 30, 'min': 1},
#       {'avg': 2, 'day': '2023-05-30', 'max': 13, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 235, 'day': '2023-05-25', 'max': 396, 'min': 123},
#       {'avg': 136, 'day': '2023-05-26', 'max': 174, 'min': 108},
#       {'avg': 115, 'day': '2023-05-27', 'max': 123, 'min': 72},
#       {'avg': 102, 'day': '2023-05-28', 'max': 123, 'min': 73},
#       {'avg': 72, 'day': '2023-05-29', 'max': 73, 'min': 63},
#       {'avg': 58, 'day': '2023-05-30', 'max': 73, 'min': 29},
#       {'avg': 48, 'day': '2023-05-31', 'max': 58, 'min': 22},
#       {'avg': 55, 'day': '2023-06-01', 'max': 72, 'min': 46}],
#      'pm25': [{'avg': 167, 'day': '2023-05-25', 'max': 252, 'min': 151},
#       {'avg': 166, 'day': '2023-05-26', 'max': 174, 'min': 138},
#       {'avg': 170, 'day': '2023-05-27', 'max': 174, 'min': 159},
#       {'avg': 190, 'day': '2023-05-28', 'max': 252, 'min': 154},
#       {'avg': 150, 'day': '2023-05-29', 'max': 159, 'min': 138},
#       {'avg': 124, 'day': '2023-05-30', 'max': 158, 'min': 74},
#       {'avg': 128, 'day': '2023-05-31', 'max': 148, 'min': 68},
#       {'avg': 136, 'day': '2023-06-01', 'max': 158, 'min': 132}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T01:28:48+09:00'}}},
#  'Tianjin': {'status': 'ok',
#   'data': {'aqi': 139,
#    'idx': 1452,
#    'attributions': [{'url': 'http://113.108.142.147:20035/emcpublish/',
#      'name': 'China National Urban air quality real-time publishing platform (全国城市空气质量实时发布平台)'},
#     {'url': 'http://www.tjemc.org.cn/',
#      'name': 'Tianjin Environmental Monitoring Center (天津市环境监测中心)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [39.084158, 117.200983],
#     'name': 'Tianjin (天津)',
#     'url': 'https://aqicn.org/city/tianjin',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 8.2},
#     'd': {'v': -1},
#     'h': {'v': 73},
#     'no2': {'v': 14.7},
#     'o3': {'v': 27},
#     'p': {'v': 1013},
#     'pm10': {'v': 64},
#     'pm25': {'v': 139},
#     'so2': {'v': 4.1},
#     't': {'v': 21},
#     'w': {'v': 1.5},
#     'wd': {'v': 170}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 29,
#        'day': '2023-05-24',
#        'max': 41,
#        'min': 18},
#       {'avg': 14, 'day': '2023-05-25', 'max': 40, 'min': 4},
#       {'avg': 13, 'day': '2023-05-26', 'max': 44, 'min': 4},
#       {'avg': 12, 'day': '2023-05-27', 'max': 24, 'min': 5},
#       {'avg': 6, 'day': '2023-05-28', 'max': 52, 'min': 1},
#       {'avg': 6, 'day': '2023-05-29', 'max': 28, 'min': 1},
#       {'avg': 3, 'day': '2023-05-30', 'max': 12, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 7, 'min': 1}],
#      'pm10': [{'avg': 130, 'day': '2023-05-25', 'max': 396, 'min': 38},
#       {'avg': 148, 'day': '2023-05-26', 'max': 174, 'min': 123},
#       {'avg': 69, 'day': '2023-05-27', 'max': 123, 'min': 46},
#       {'avg': 81, 'day': '2023-05-28', 'max': 123, 'min': 50},
#       {'avg': 62, 'day': '2023-05-29', 'max': 73, 'min': 58},
#       {'avg': 43, 'day': '2023-05-30', 'max': 58, 'min': 21},
#       {'avg': 38, 'day': '2023-05-31', 'max': 46, 'min': 28},
#       {'avg': 51, 'day': '2023-06-01', 'max': 56, 'min': 46}],
#      'pm25': [{'avg': 138, 'day': '2023-05-25', 'max': 252, 'min': 68},
#       {'avg': 167, 'day': '2023-05-26', 'max': 174, 'min': 159},
#       {'avg': 134, 'day': '2023-05-27', 'max': 163, 'min': 89},
#       {'avg': 153, 'day': '2023-05-28', 'max': 165, 'min': 108},
#       {'avg': 140, 'day': '2023-05-29', 'max': 156, 'min': 138},
#       {'avg': 106, 'day': '2023-05-30', 'max': 138, 'min': 55},
#       {'avg': 87, 'day': '2023-05-31', 'max': 89, 'min': 68},
#       {'avg': 130, 'day': '2023-06-01', 'max': 138, 'min': 78}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T00:36:12+09:00'}}},
#  'Guangzhou': {'status': 'ok',
#   'data': {'aqi': 59,
#    'idx': 1449,
#    'attributions': [{'url': 'https://china.usembassy-china.org.cn/embassy-consulates/guangzhou/u-s-consulate-air-quality-monitor-stateair/',
#      'name': 'U.S. Consulate Guangzhou Air Quality Monitor'},
#     {'url': 'http://sthjj.gz.gov.cn/',
#      'name': 'Guangzhou Environmental Protection Bureau (广州市生态环境局)'},
#     {'url': 'http://106.37.208.233:20035/emcpublish/',
#      'name': 'China National Urban air quality real-time publishing platform (全国城市空气质量实时发布平台)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [23.141191, 113.258374],
#     'name': 'Guangzhou (广州)',
#     'url': 'https://aqicn.org/city/guangzhou',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 5.1},
#     'h': {'v': 83},
#     'no2': {'v': 9.2},
#     'o3': {'v': 11},
#     'p': {'v': 1011},
#     'pm10': {'v': 26},
#     'pm25': {'v': 59},
#     'so2': {'v': 2.1},
#     't': {'v': 29},
#     'w': {'v': 3}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 1,
#        'day': '2023-05-25',
#        'max': 8,
#        'min': 1},
#       {'avg': 1, 'day': '2023-05-26', 'max': 14, 'min': 1},
#       {'avg': 7, 'day': '2023-05-27', 'max': 31, 'min': 1},
#       {'avg': 7, 'day': '2023-05-28', 'max': 54, 'min': 1},
#       {'avg': 6, 'day': '2023-05-29', 'max': 40, 'min': 1},
#       {'avg': 9, 'day': '2023-05-30', 'max': 40, 'min': 1},
#       {'avg': 4, 'day': '2023-05-31', 'max': 9, 'min': 2}],
#      'pm10': [{'avg': 55, 'day': '2023-05-25', 'max': 73, 'min': 28},
#       {'avg': 66, 'day': '2023-05-26', 'max': 123, 'min': 25},
#       {'avg': 54, 'day': '2023-05-27', 'max': 68, 'min': 35},
#       {'avg': 81, 'day': '2023-05-28', 'max': 123, 'min': 46},
#       {'avg': 74, 'day': '2023-05-29', 'max': 123, 'min': 46},
#       {'avg': 50, 'day': '2023-05-30', 'max': 58, 'min': 35},
#       {'avg': 59, 'day': '2023-05-31', 'max': 71, 'min': 46},
#       {'avg': 69, 'day': '2023-06-01', 'max': 73, 'min': 58}],
#      'pm25': [{'avg': 134, 'day': '2023-05-25', 'max': 163, 'min': 89},
#       {'avg': 141, 'day': '2023-05-26', 'max': 252, 'min': 68},
#       {'avg': 134, 'day': '2023-05-27', 'max': 169, 'min': 89},
#       {'avg': 176, 'day': '2023-05-28', 'max': 252, 'min': 138},
#       {'avg': 175, 'day': '2023-05-29', 'max': 252, 'min': 138},
#       {'avg': 143, 'day': '2023-05-30', 'max': 159, 'min': 89},
#       {'avg': 159, 'day': '2023-05-31', 'max': 172, 'min': 138},
#       {'avg': 168, 'day': '2023-06-01', 'max': 174, 'min': 159}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T01:29:55+09:00'}}},
#  'Shenzhen': {'status': 'ok',
#   'data': {'aqi': 65,
#    'idx': 1539,
#    'attributions': [{'url': 'http://meeb.sz.gov.cn/',
#      'name': 'Shenzhen Environment Network (深圳人居环境网)'},
#     {'url': 'http://gdee.gd.gov.cn/',
#      'name': 'Guangdong Environmental Protection public network (广东环境保护公众网)'},
#     {'url': 'http://www.szhec.gov.cn/',
#      'name': 'Shenzhen Environment Network (深圳人居环境网)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [22.543099, 114.057868],
#     'name': 'Shenzhen (深圳)',
#     'url': 'https://aqicn.org/city/shenzhen',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 7.3},
#     'd': {'v': 16},
#     'h': {'v': 78},
#     'no2': {'v': 9.2},
#     'o3': {'v': 24.4},
#     'p': {'v': 1011},
#     'pm10': {'v': 34},
#     'pm25': {'v': 65},
#     'so2': {'v': 3.1},
#     't': {'v': 28.3},
#     'w': {'v': 3.6},
#     'wd': {'v': 60}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 17,
#        'day': '2023-05-24',
#        'max': 19,
#        'min': 15},
#       {'avg': 8, 'day': '2023-05-25', 'max': 18, 'min': 6},
#       {'avg': 7, 'day': '2023-05-26', 'max': 16, 'min': 4},
#       {'avg': 12, 'day': '2023-05-27', 'max': 24, 'min': 8},
#       {'avg': 14, 'day': '2023-05-28', 'max': 30, 'min': 8},
#       {'avg': 7, 'day': '2023-05-29', 'max': 51, 'min': 1},
#       {'avg': 8, 'day': '2023-05-30', 'max': 47, 'min': 1},
#       {'avg': 5, 'day': '2023-05-31', 'max': 8, 'min': 1}],
#      'pm10': [{'avg': 40, 'day': '2023-05-25', 'max': 46, 'min': 29},
#       {'avg': 44, 'day': '2023-05-26', 'max': 73, 'min': 19},
#       {'avg': 45, 'day': '2023-05-27', 'max': 46, 'min': 29},
#       {'avg': 47, 'day': '2023-05-28', 'max': 55, 'min': 46},
#       {'avg': 67, 'day': '2023-05-29', 'max': 73, 'min': 58},
#       {'avg': 55, 'day': '2023-05-30', 'max': 73, 'min': 46},
#       {'avg': 59, 'day': '2023-05-31', 'max': 73, 'min': 47},
#       {'avg': 63, 'day': '2023-06-01', 'max': 73, 'min': 47}],
#      'pm25': [{'avg': 100, 'day': '2023-05-25', 'max': 138, 'min': 68},
#       {'avg': 113, 'day': '2023-05-26', 'max': 159, 'min': 68},
#       {'avg': 90, 'day': '2023-05-27', 'max': 90, 'min': 68},
#       {'avg': 131, 'day': '2023-05-28', 'max': 155, 'min': 90},
#       {'avg': 165, 'day': '2023-05-29', 'max': 174, 'min': 159},
#       {'avg': 151, 'day': '2023-05-30', 'max': 174, 'min': 138},
#       {'avg': 154, 'day': '2023-05-31', 'max': 174, 'min': 139},
#       {'avg': 161, 'day': '2023-06-01', 'max': 174, 'min': 139}],
#      'uvi': [{'avg': 0, 'day': '2020-12-03', 'max': 0, 'min': 0},
#       {'avg': 1, 'day': '2020-12-04', 'max': 6, 'min': 0},
#       {'avg': 1, 'day': '2020-12-05', 'max': 6, 'min': 0},
#       {'avg': 1, 'day': '2020-12-06', 'max': 6, 'min': 0},
#       {'avg': 1, 'day': '2020-12-07', 'max': 4, 'min': 0},
#       {'avg': 2, 'day': '2020-12-08', 'max': 5, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T00:36:16+09:00'}}},
#  'Wuhan': {'status': 'ok',
#   'data': {'aqi': '-',
#    'idx': 1529,
#    'attributions': [{'url': 'http://www.whepb.gov.cn/',
#      'name': 'Wuhan Environmental Protection Bureau (武汉市环保局)'},
#     {'url': 'http://www.hbepb.gov.cn/',
#      'name': 'Hubei Environmental Protection Agency (湖北省环境保护厅)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [30.593099, 114.305393],
#     'name': 'Wuhan (武汉)',
#     'url': 'https://aqicn.org/city/wuhan',
#     'location': ''},
#    'dominentpol': '',
#    'iaqi': {'h': {'v': 94}, 'p': {'v': 1008}, 't': {'v': 23}, 'w': {'v': 2.5}},
#    'time': {'tz': '+08:00', 'v': 0},
#    'forecast': {'daily': {'o3': [{'avg': 3,
#        'day': '2023-05-24',
#        'max': 28,
#        'min': 1},
#       {'avg': 1, 'day': '2023-05-25', 'max': 10, 'min': 1},
#       {'avg': 1, 'day': '2023-05-26', 'max': 1, 'min': 1},
#       {'avg': 2, 'day': '2023-05-27', 'max': 16, 'min': 1},
#       {'avg': 4, 'day': '2023-05-28', 'max': 38, 'min': 1},
#       {'avg': 2, 'day': '2023-05-29', 'max': 10, 'min': 1},
#       {'avg': 10, 'day': '2023-05-30', 'max': 25, 'min': 1},
#       {'avg': 8, 'day': '2023-05-31', 'max': 13, 'min': 5}],
#      'pm10': [{'avg': 67, 'day': '2023-05-24', 'max': 73, 'min': 58},
#       {'avg': 58, 'day': '2023-05-25', 'max': 58, 'min': 58},
#       {'avg': 49, 'day': '2023-05-26', 'max': 58, 'min': 46},
#       {'avg': 48, 'day': '2023-05-27', 'max': 58, 'min': 28},
#       {'avg': 54, 'day': '2023-05-28', 'max': 73, 'min': 46},
#       {'avg': 52, 'day': '2023-05-29', 'max': 58, 'min': 46},
#       {'avg': 31, 'day': '2023-05-30', 'max': 46, 'min': 28},
#       {'avg': 43, 'day': '2023-05-31', 'max': 46, 'min': 28},
#       {'avg': 46, 'day': '2023-06-01', 'max': 46, 'min': 46}],
#      'pm25': [{'avg': 154, 'day': '2023-05-24', 'max': 173, 'min': 138},
#       {'avg': 151, 'day': '2023-05-25', 'max': 159, 'min': 138},
#       {'avg': 143, 'day': '2023-05-26', 'max': 159, 'min': 138},
#       {'avg': 137, 'day': '2023-05-27', 'max': 159, 'min': 89},
#       {'avg': 150, 'day': '2023-05-28', 'max': 174, 'min': 138},
#       {'avg': 148, 'day': '2023-05-29', 'max': 158, 'min': 138},
#       {'avg': 90, 'day': '2023-05-30', 'max': 138, 'min': 68},
#       {'avg': 107, 'day': '2023-05-31', 'max': 138, 'min': 68},
#       {'avg': 123, 'day': '2023-06-01', 'max': 138, 'min': 89}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T01:29:54+09:00'}}},
#  'Dongguan': {'status': 'ok',
#   'data': {'aqi': 46,
#    'idx': 1547,
#    'attributions': [{'url': 'http://gdee.gd.gov.cn/',
#      'name': 'Guangdong Environmental Protection public network (广东环境保护公众网)'},
#     {'url': 'http://www.gdep.gov.cn/',
#      'name': 'Guangdong Environmental Protection public network (广东环境保护公众网)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [23.020536, 113.751765],
#     'name': 'Dongguan (东莞)',
#     'url': 'https://aqicn.org/city/dongguan',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 6.4},
#     'h': {'v': 78},
#     'no2': {'v': 13.3},
#     'o3': {'v': 30.5},
#     'p': {'v': 1011},
#     'pm10': {'v': 29},
#     'pm25': {'v': 46},
#     'so2': {'v': 3.6},
#     't': {'v': 28},
#     'w': {'v': 3.6}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 6,
#        'day': '2023-05-24',
#        'max': 11,
#        'min': 4},
#       {'avg': 3, 'day': '2023-05-25', 'max': 10, 'min': 1},
#       {'avg': 2, 'day': '2023-05-26', 'max': 17, 'min': 1},
#       {'avg': 6, 'day': '2023-05-27', 'max': 40, 'min': 1},
#       {'avg': 13, 'day': '2023-05-28', 'max': 50, 'min': 1},
#       {'avg': 12, 'day': '2023-05-29', 'max': 48, 'min': 1},
#       {'avg': 17, 'day': '2023-05-30', 'max': 43, 'min': 1},
#       {'avg': 6, 'day': '2023-05-31', 'max': 17, 'min': 2}],
#      'pm10': [{'avg': 45, 'day': '2023-05-25', 'max': 58, 'min': 28},
#       {'avg': 52, 'day': '2023-05-26', 'max': 73, 'min': 24},
#       {'avg': 50, 'day': '2023-05-27', 'max': 58, 'min': 42},
#       {'avg': 54, 'day': '2023-05-28', 'max': 62, 'min': 46},
#       {'avg': 60, 'day': '2023-05-29', 'max': 73, 'min': 58},
#       {'avg': 53, 'day': '2023-05-30', 'max': 70, 'min': 42},
#       {'avg': 53, 'day': '2023-05-31', 'max': 61, 'min': 46},
#       {'avg': 67, 'day': '2023-06-01', 'max': 73, 'min': 58}],
#      'pm25': [{'avg': 118, 'day': '2023-05-25', 'max': 138, 'min': 89},
#       {'avg': 124, 'day': '2023-05-26', 'max': 174, 'min': 68},
#       {'avg': 125, 'day': '2023-05-27', 'max': 155, 'min': 89},
#       {'avg': 142, 'day': '2023-05-28', 'max': 155, 'min': 138},
#       {'avg': 160, 'day': '2023-05-29', 'max': 174, 'min': 159},
#       {'avg': 148, 'day': '2023-05-30', 'max': 159, 'min': 126},
#       {'avg': 153, 'day': '2023-05-31', 'max': 162, 'min': 138},
#       {'avg': 168, 'day': '2023-06-01', 'max': 174, 'min': 159}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T00:37:23+09:00'}}},
#  'Chongqing': {'status': 'ok',
#   'data': {'aqi': 153,
#    'idx': 1453,
#    'attributions': [{'url': 'http://www.cepb.gov.cn/',
#      'name': 'Chongqing Environmental Protection Bureau (重庆市主城区空气质量)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [29.56301, 106.551557],
#     'name': 'Chongqing (重庆)',
#     'url': 'https://aqicn.org/city/chongqing',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 10.9},
#     'd': {'v': 8},
#     'h': {'v': 88},
#     'no2': {'v': 38.4},
#     'o3': {'v': 3.7},
#     'p': {'v': 1006},
#     'pm10': {'v': 77},
#     'pm25': {'v': 153},
#     'so2': {'v': 3.1},
#     't': {'v': 22},
#     'w': {'v': 2.5},
#     'wd': {'v': 330}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 2,
#        'day': '2023-05-25',
#        'max': 7,
#        'min': 1},
#       {'avg': 6, 'day': '2023-05-26', 'max': 27, 'min': 1},
#       {'avg': 7, 'day': '2023-05-27', 'max': 20, 'min': 1},
#       {'avg': 10, 'day': '2023-05-28', 'max': 27, 'min': 1},
#       {'avg': 15, 'day': '2023-05-29', 'max': 56, 'min': 1},
#       {'avg': 4, 'day': '2023-05-30', 'max': 13, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 46, 'day': '2023-05-25', 'max': 47, 'min': 46},
#       {'avg': 50, 'day': '2023-05-26', 'max': 58, 'min': 46},
#       {'avg': 46, 'day': '2023-05-27', 'max': 46, 'min': 46},
#       {'avg': 46, 'day': '2023-05-28', 'max': 46, 'min': 46},
#       {'avg': 46, 'day': '2023-05-29', 'max': 46, 'min': 46},
#       {'avg': 45, 'day': '2023-05-30', 'max': 46, 'min': 37},
#       {'avg': 28, 'day': '2023-05-31', 'max': 32, 'min': 28},
#       {'avg': 34, 'day': '2023-06-01', 'max': 46, 'min': 27}],
#      'pm25': [{'avg': 138, 'day': '2023-05-25', 'max': 138, 'min': 138},
#       {'avg': 145, 'day': '2023-05-26', 'max': 158, 'min': 138},
#       {'avg': 138, 'day': '2023-05-27', 'max': 138, 'min': 138},
#       {'avg': 138, 'day': '2023-05-28', 'max': 138, 'min': 138},
#       {'avg': 138, 'day': '2023-05-29', 'max': 138, 'min': 138},
#       {'avg': 134, 'day': '2023-05-30', 'max': 138, 'min': 104},
#       {'avg': 89, 'day': '2023-05-31', 'max': 89, 'min': 89},
#       {'avg': 94, 'day': '2023-06-01', 'max': 133, 'min': 87}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 0, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T01:26:34+09:00'}}},
#  'Chengdu': {'status': 'ok',
#   'data': {'aqi': 151,
#    'idx': 1450,
#    'attributions': [{'url': 'https://sthjt.sc.gov.cn/',
#      'name': 'Sichuan Province Environmental Protection Agency (四川省环保重点城市环境空气质量实时监测结果)'},
#     {'url': 'http://sthj.chengdu.gov.cn/',
#      'name': 'Chengdu Environmental Protection Agency (成都市环境监测中心站_成都市环境监测中心站)'},
#     {'url': 'http://106.37.208.233:20035/emcpublish/',
#      'name': 'China National Urban air quality real-time publishing platform (全国城市空气质量实时发布平台)'},
#     {'url': 'https://china.usembassy-china.org.cn/embassy-consulates/chengdu/air-quality-monitor/',
#      'name': 'U.S. Consulate Chengdu Air Quality Monitor'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [30.6250145, 104.0670559],
#     'name': 'Chengdu (成都)',
#     'url': 'https://aqicn.org/city/chengdu',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 6.4},
#     'h': {'v': 64},
#     'no2': {'v': 26.6},
#     'o3': {'v': 27.7},
#     'p': {'v': 1007},
#     'pm10': {'v': 68},
#     'pm25': {'v': 151},
#     'so2': {'v': 1.6},
#     't': {'v': 23},
#     'w': {'v': 0.5}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 4,
#        'day': '2023-05-25',
#        'max': 15,
#        'min': 1},
#       {'avg': 3, 'day': '2023-05-26', 'max': 26, 'min': 1},
#       {'avg': 5, 'day': '2023-05-27', 'max': 17, 'min': 1},
#       {'avg': 6, 'day': '2023-05-28', 'max': 44, 'min': 1},
#       {'avg': 7, 'day': '2023-05-29', 'max': 49, 'min': 1},
#       {'avg': 3, 'day': '2023-05-30', 'max': 12, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 51, 'day': '2023-05-25', 'max': 58, 'min': 46},
#       {'avg': 53, 'day': '2023-05-26', 'max': 58, 'min': 46},
#       {'avg': 46, 'day': '2023-05-27', 'max': 46, 'min': 46},
#       {'avg': 43, 'day': '2023-05-28', 'max': 46, 'min': 28},
#       {'avg': 45, 'day': '2023-05-29', 'max': 46, 'min': 28},
#       {'avg': 47, 'day': '2023-05-30', 'max': 56, 'min': 33},
#       {'avg': 47, 'day': '2023-05-31', 'max': 58, 'min': 28},
#       {'avg': 46, 'day': '2023-06-01', 'max': 46, 'min': 28}],
#      'pm25': [{'avg': 142, 'day': '2023-05-25', 'max': 159, 'min': 137},
#       {'avg': 149, 'day': '2023-05-26', 'max': 159, 'min': 138},
#       {'avg': 138, 'day': '2023-05-27', 'max': 138, 'min': 138},
#       {'avg': 113, 'day': '2023-05-28', 'max': 138, 'min': 89},
#       {'avg': 134, 'day': '2023-05-29', 'max': 138, 'min': 89},
#       {'avg': 118, 'day': '2023-05-30', 'max': 138, 'min': 89},
#       {'avg': 138, 'day': '2023-05-31', 'max': 159, 'min': 89},
#       {'avg': 131, 'day': '2023-06-01', 'max': 138, 'min': 89}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 0, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T01:29:57+09:00'}}},
#  'Nanjing': {'status': 'ok',
#   'data': {'aqi': 122,
#    'idx': 1485,
#    'attributions': [{'url': 'http://hbt.jiangsu.gov.cn/',
#      'name': 'Jiangsu Environmental Protection public network (江苏省城市空气PM2.5等试运行监测数据平台)'},
#     {'url': 'http://222.190.111.117:8023/',
#      'name': 'Nanjing Air Quality Distribution System (南京空气质量发布系统)'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [32.060255, 118.796877],
#     'name': 'Nanjing (南京)',
#     'url': 'https://aqicn.org/city/nanjing',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 9.1},
#     'h': {'v': 100},
#     'no2': {'v': 8.7},
#     'p': {'v': 1010},
#     'pm10': {'v': 51},
#     'pm25': {'v': 122},
#     'so2': {'v': 2.6},
#     't': {'v': 22},
#     'w': {'v': 1.5}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 11,
#        'day': '2023-05-24',
#        'max': 21,
#        'min': 7},
#       {'avg': 6, 'day': '2023-05-25', 'max': 23, 'min': 1},
#       {'avg': 4, 'day': '2023-05-26', 'max': 21, 'min': 1},
#       {'avg': 10, 'day': '2023-05-27', 'max': 23, 'min': 2},
#       {'avg': 6, 'day': '2023-05-28', 'max': 34, 'min': 1},
#       {'avg': 1, 'day': '2023-05-29', 'max': 5, 'min': 1},
#       {'avg': 1, 'day': '2023-05-30', 'max': 8, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 55, 'day': '2023-05-25', 'max': 58, 'min': 46},
#       {'avg': 60, 'day': '2023-05-26', 'max': 73, 'min': 46},
#       {'avg': 80, 'day': '2023-05-27', 'max': 123, 'min': 46},
#       {'avg': 46, 'day': '2023-05-28', 'max': 46, 'min': 46},
#       {'avg': 43, 'day': '2023-05-29', 'max': 58, 'min': 28},
#       {'avg': 68, 'day': '2023-05-30', 'max': 73, 'min': 28},
#       {'avg': 45, 'day': '2023-05-31', 'max': 73, 'min': 25},
#       {'avg': 29, 'day': '2023-06-01', 'max': 34, 'min': 25}],
#      'pm25': [{'avg': 145, 'day': '2023-05-25', 'max': 159, 'min': 138},
#       {'avg': 153, 'day': '2023-05-26', 'max': 174, 'min': 138},
#       {'avg': 175, 'day': '2023-05-27', 'max': 252, 'min': 94},
#       {'avg': 134, 'day': '2023-05-28', 'max': 138, 'min': 89},
#       {'avg': 125, 'day': '2023-05-29', 'max': 159, 'min': 89},
#       {'avg': 165, 'day': '2023-05-30', 'max': 174, 'min': 89},
#       {'avg': 121, 'day': '2023-05-31', 'max': 174, 'min': 68},
#       {'avg': 79, 'day': '2023-06-01', 'max': 89, 'min': 68}],
#      'uvi': [{'avg': 0, 'day': '2022-10-24', 'max': 1, 'min': 0}]}},
#    'debug': {'sync': '2023-05-27T00:37:22+09:00'}}},
#  'Taipei': {'status': 'ok',
#   'data': {'aqi': 50,
#    'idx': 1597,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [25.062361, 121.526528],
#     'name': 'Zhongshan, Taiwan (中山)',
#     'url': 'https://aqicn.org/city/taiwan/jhongshan',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 4.3},
#     'dew': {'v': 22},
#     'h': {'v': 76},
#     'no2': {'v': 12.1},
#     'o3': {'v': 20.9},
#     'p': {'v': 1012},
#     'pm10': {'v': 26},
#     'pm25': {'v': 50},
#     'so2': {'v': 0.3},
#     't': {'v': 26.5},
#     'w': {'v': 5.1},
#     'wg': {'v': 11.3}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 8,
#        'day': '2023-05-25',
#        'max': 29,
#        'min': 1},
#       {'avg': 12, 'day': '2023-05-26', 'max': 40, 'min': 2},
#       {'avg': 16, 'day': '2023-05-27', 'max': 24, 'min': 11},
#       {'avg': 11, 'day': '2023-05-28', 'max': 17, 'min': 7},
#       {'avg': 6, 'day': '2023-05-29', 'max': 9, 'min': 5},
#       {'avg': 6, 'day': '2023-05-30', 'max': 8, 'min': 4},
#       {'avg': 5, 'day': '2023-05-31', 'max': 6, 'min': 4}],
#      'pm10': [{'avg': 46, 'day': '2023-05-25', 'max': 46, 'min': 46},
#       {'avg': 46, 'day': '2023-05-26', 'max': 46, 'min': 45},
#       {'avg': 39, 'day': '2023-05-27', 'max': 46, 'min': 28},
#       {'avg': 21, 'day': '2023-05-28', 'max': 28, 'min': 18},
#       {'avg': 28, 'day': '2023-05-29', 'max': 43, 'min': 21},
#       {'avg': 31, 'day': '2023-05-30', 'max': 44, 'min': 28},
#       {'avg': 24, 'day': '2023-05-31', 'max': 28, 'min': 21},
#       {'avg': 48, 'day': '2023-06-01', 'max': 58, 'min': 21}],
#      'pm25': [{'avg': 102, 'day': '2023-05-25', 'max': 138, 'min': 89},
#       {'avg': 89, 'day': '2023-05-26', 'max': 92, 'min': 78},
#       {'avg': 75, 'day': '2023-05-27', 'max': 89, 'min': 68},
#       {'avg': 37, 'day': '2023-05-28', 'max': 68, 'min': 21},
#       {'avg': 29, 'day': '2023-05-29', 'max': 33, 'min': 23},
#       {'avg': 41, 'day': '2023-05-30', 'max': 52, 'min': 30},
#       {'avg': 38, 'day': '2023-05-31', 'max': 55, 'min': 30},
#       {'avg': 101, 'day': '2023-06-01', 'max': 138, 'min': 30}]}},
#    'debug': {'sync': '2023-05-27T01:09:15+09:00'}}},
#  'Kaohsiung': {'status': 'ok',
#   'data': {'aqi': 53,
#    'idx': 1655,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [22.608711, 120.312017],
#     'name': 'Fuxing, Taiwan (復興)',
#     'url': 'https://aqicn.org/city/taiwan/fusing',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 3.3},
#     'h': {'v': 87},
#     'no2': {'v': 9.1},
#     'o3': {'v': 17.7},
#     'p': {'v': 1012},
#     'pm10': {'v': 16},
#     'pm25': {'v': 53},
#     'so2': {'v': 1.5},
#     't': {'v': 27.1},
#     'w': {'v': 1.6},
#     'wg': {'v': 7}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 21,
#        'day': '2023-05-25',
#        'max': 41,
#        'min': 4},
#       {'avg': 16, 'day': '2023-05-26', 'max': 30, 'min': 9},
#       {'avg': 13, 'day': '2023-05-27', 'max': 23, 'min': 7},
#       {'avg': 19, 'day': '2023-05-28', 'max': 29, 'min': 15},
#       {'avg': 20, 'day': '2023-05-29', 'max': 43, 'min': 14},
#       {'avg': 13, 'day': '2023-05-30', 'max': 29, 'min': 7},
#       {'avg': 14, 'day': '2023-05-31', 'max': 15, 'min': 10}],
#      'pm10': [{'avg': 51, 'day': '2023-05-25', 'max': 56, 'min': 41},
#       {'avg': 50, 'day': '2023-05-26', 'max': 56, 'min': 46},
#       {'avg': 50, 'day': '2023-05-27', 'max': 58, 'min': 46},
#       {'avg': 50, 'day': '2023-05-28', 'max': 58, 'min': 46},
#       {'avg': 48, 'day': '2023-05-29', 'max': 63, 'min': 32},
#       {'avg': 59, 'day': '2023-05-30', 'max': 70, 'min': 49},
#       {'avg': 47, 'day': '2023-05-31', 'max': 57, 'min': 43},
#       {'avg': 50, 'day': '2023-06-01', 'max': 58, 'min': 46}],
#      'pm25': [{'avg': 138, 'day': '2023-05-25', 'max': 144, 'min': 122},
#       {'avg': 144, 'day': '2023-05-26', 'max': 157, 'min': 122},
#       {'avg': 139, 'day': '2023-05-27', 'max': 155, 'min': 130},
#       {'avg': 117, 'day': '2023-05-28', 'max': 145, 'min': 89},
#       {'avg': 80, 'day': '2023-05-29', 'max': 95, 'min': 68},
#       {'avg': 83, 'day': '2023-05-30', 'max': 95, 'min': 68},
#       {'avg': 84, 'day': '2023-05-31', 'max': 95, 'min': 68},
#       {'avg': 133, 'day': '2023-06-01', 'max': 138, 'min': 89}]}},
#    'debug': {'sync': '2023-05-27T01:14:51+09:00'}}},
#  'Taichung': {'status': 'ok',
#   'data': {'aqi': 68,
#    'idx': 1615,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [24.099611, 120.677689],
#     'name': 'Dali, Taiwan (大里)',
#     'url': 'https://aqicn.org/city/taiwan/dali',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 4.5},
#     'h': {'v': 88},
#     'no2': {'v': 14.8},
#     'o3': {'v': 19.2},
#     'p': {'v': 1012.9},
#     'pm10': {'v': 45},
#     'pm25': {'v': 68},
#     'so2': {'v': 2.2},
#     't': {'v': 27.1},
#     'w': {'v': 0.9}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 8,
#        'day': '2023-05-24',
#        'max': 28,
#        'min': 1},
#       {'avg': 7, 'day': '2023-05-25', 'max': 42, 'min': 1},
#       {'avg': 6, 'day': '2023-05-26', 'max': 35, 'min': 1},
#       {'avg': 7, 'day': '2023-05-27', 'max': 23, 'min': 1},
#       {'avg': 9, 'day': '2023-05-28', 'max': 41, 'min': 1},
#       {'avg': 12, 'day': '2023-05-29', 'max': 64, 'min': 1},
#       {'avg': 7, 'day': '2023-05-30', 'max': 61, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 2, 'min': 1}],
#      'pm10': [{'avg': 45, 'day': '2023-05-25', 'max': 46, 'min': 37},
#       {'avg': 46, 'day': '2023-05-26', 'max': 46, 'min': 46},
#       {'avg': 47, 'day': '2023-05-27', 'max': 47, 'min': 46},
#       {'avg': 30, 'day': '2023-05-28', 'max': 46, 'min': 23},
#       {'avg': 24, 'day': '2023-05-29', 'max': 30, 'min': 20},
#       {'avg': 23, 'day': '2023-05-30', 'max': 31, 'min': 20},
#       {'avg': 20, 'day': '2023-05-31', 'max': 21, 'min': 20},
#       {'avg': 44, 'day': '2023-06-01', 'max': 58, 'min': 20}],
#      'pm25': [{'avg': 91, 'day': '2023-05-25', 'max': 92, 'min': 89},
#       {'avg': 114, 'day': '2023-05-26', 'max': 138, 'min': 89},
#       {'avg': 106, 'day': '2023-05-27', 'max': 138, 'min': 68},
#       {'avg': 58, 'day': '2023-05-28', 'max': 69, 'min': 42},
#       {'avg': 36, 'day': '2023-05-29', 'max': 56, 'min': 26},
#       {'avg': 38, 'day': '2023-05-30', 'max': 45, 'min': 31},
#       {'avg': 46, 'day': '2023-05-31', 'max': 56, 'min': 35},
#       {'avg': 103, 'day': '2023-06-01', 'max': 138, 'min': 45}]}},
#    'debug': {'sync': '2023-05-27T00:11:10+09:00'}}},
#  'tainan': {'status': 'ok',
#   'data': {'aqi': 55,
#    'idx': 1631,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [22.984581, 120.202617],
#     'name': 'Tainan, Taiwan (台南)',
#     'url': 'https://aqicn.org/city/taiwan/tainan',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 2.9},
#     'dew': {'v': 22},
#     'h': {'v': 72},
#     'no2': {'v': 9.4},
#     'o3': {'v': 11.2},
#     'p': {'v': 1012.5},
#     'pm10': {'v': 24},
#     'pm25': {'v': 55},
#     'so2': {'v': 2.6},
#     't': {'v': 27.9},
#     'uvi': {'v': 2},
#     'w': {'v': 0.5}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 8,
#        'day': '2023-05-25',
#        'max': 43,
#        'min': 1},
#       {'avg': 9, 'day': '2023-05-26', 'max': 37, 'min': 1},
#       {'avg': 7, 'day': '2023-05-27', 'max': 27, 'min': 1},
#       {'avg': 11, 'day': '2023-05-28', 'max': 29, 'min': 1},
#       {'avg': 12, 'day': '2023-05-29', 'max': 44, 'min': 1},
#       {'avg': 7, 'day': '2023-05-30', 'max': 38, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 51, 'day': '2023-05-25', 'max': 58, 'min': 46},
#       {'avg': 48, 'day': '2023-05-26', 'max': 57, 'min': 46},
#       {'avg': 51, 'day': '2023-05-27', 'max': 58, 'min': 46},
#       {'avg': 43, 'day': '2023-05-28', 'max': 57, 'min': 32},
#       {'avg': 41, 'day': '2023-05-29', 'max': 57, 'min': 21},
#       {'avg': 51, 'day': '2023-05-30', 'max': 57, 'min': 45},
#       {'avg': 40, 'day': '2023-05-31', 'max': 47, 'min': 31},
#       {'avg': 48, 'day': '2023-06-01', 'max': 57, 'min': 32}],
#      'pm25': [{'avg': 142, 'day': '2023-05-25', 'max': 158, 'min': 99},
#       {'avg': 140, 'day': '2023-05-26', 'max': 150, 'min': 132},
#       {'avg': 130, 'day': '2023-05-27', 'max': 159, 'min': 99},
#       {'avg': 111, 'day': '2023-05-28', 'max': 150, 'min': 73},
#       {'avg': 79, 'day': '2023-05-29', 'max': 97, 'min': 66},
#       {'avg': 79, 'day': '2023-05-30', 'max': 99, 'min': 66},
#       {'avg': 78, 'day': '2023-05-31', 'max': 97, 'min': 65},
#       {'avg': 130, 'day': '2023-06-01', 'max': 138, 'min': 73}]}},
#    'debug': {'sync': '2023-05-27T01:14:56+09:00'}}},
#  'banqiao': {'status': 'ok',
#   'data': {'aqi': 50,
#    'idx': 1591,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [25.012972, 121.458667],
#     'name': 'Banqiao, Taiwan (板橋)',
#     'url': 'https://aqicn.org/city/taiwan/banciao',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 2.9},
#     'dew': {'v': 22},
#     'h': {'v': 77},
#     'no2': {'v': 7.3},
#     'o3': {'v': 22.2},
#     'p': {'v': 1012.1},
#     'pm10': {'v': 21},
#     'pm25': {'v': 50},
#     'so2': {'v': 0.2},
#     't': {'v': 25.9},
#     'uvi': {'v': 2},
#     'w': {'v': 2.7},
#     'wg': {'v': 11.3}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 8,
#        'day': '2023-05-25',
#        'max': 29,
#        'min': 1},
#       {'avg': 12, 'day': '2023-05-26', 'max': 40, 'min': 2},
#       {'avg': 16, 'day': '2023-05-27', 'max': 24, 'min': 11},
#       {'avg': 11, 'day': '2023-05-28', 'max': 17, 'min': 7},
#       {'avg': 6, 'day': '2023-05-29', 'max': 9, 'min': 5},
#       {'avg': 6, 'day': '2023-05-30', 'max': 8, 'min': 4},
#       {'avg': 5, 'day': '2023-05-31', 'max': 6, 'min': 4}],
#      'pm10': [{'avg': 46, 'day': '2023-05-25', 'max': 46, 'min': 46},
#       {'avg': 46, 'day': '2023-05-26', 'max': 46, 'min': 45},
#       {'avg': 39, 'day': '2023-05-27', 'max': 46, 'min': 28},
#       {'avg': 21, 'day': '2023-05-28', 'max': 28, 'min': 18},
#       {'avg': 28, 'day': '2023-05-29', 'max': 43, 'min': 21},
#       {'avg': 31, 'day': '2023-05-30', 'max': 44, 'min': 28},
#       {'avg': 24, 'day': '2023-05-31', 'max': 28, 'min': 21},
#       {'avg': 48, 'day': '2023-06-01', 'max': 58, 'min': 21}],
#      'pm25': [{'avg': 102, 'day': '2023-05-25', 'max': 138, 'min': 89},
#       {'avg': 89, 'day': '2023-05-26', 'max': 92, 'min': 78},
#       {'avg': 75, 'day': '2023-05-27', 'max': 89, 'min': 68},
#       {'avg': 37, 'day': '2023-05-28', 'max': 68, 'min': 21},
#       {'avg': 29, 'day': '2023-05-29', 'max': 33, 'min': 23},
#       {'avg': 41, 'day': '2023-05-30', 'max': 52, 'min': 30},
#       {'avg': 38, 'day': '2023-05-31', 'max': 55, 'min': 30},
#       {'avg': 101, 'day': '2023-06-01', 'max': 138, 'min': 30}]}},
#    'debug': {'sync': '2023-05-27T01:14:56+09:00'}}},
#  'hsinchu': {'status': 'ok',
#   'data': {'aqi': 70,
#    'idx': 1609,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [24.805619, 120.972075],
#     'name': 'Hsinchu, Taiwan (新竹)',
#     'url': 'https://aqicn.org/city/taiwan/hsinchu',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 5.8},
#     'h': {'v': 88},
#     'no2': {'v': 21.6},
#     'o3': {'v': 5.3},
#     'p': {'v': 1007.7},
#     'pm10': {'v': 48},
#     'pm25': {'v': 70},
#     'so2': {'v': 1.2},
#     't': {'v': 25.8},
#     'uvi': {'v': 1},
#     'w': {'v': 0.3},
#     'wg': {'v': 6}},
#    'time': {'s': '2023-05-27 00:00:00',
#     'tz': '+08:00',
#     'v': 1685145600,
#     'iso': '2023-05-27T00:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 7,
#        'day': '2023-05-25',
#        'max': 30,
#        'min': 1},
#       {'avg': 8, 'day': '2023-05-26', 'max': 29, 'min': 1},
#       {'avg': 10, 'day': '2023-05-27', 'max': 41, 'min': 1},
#       {'avg': 10, 'day': '2023-05-28', 'max': 43, 'min': 1},
#       {'avg': 5, 'day': '2023-05-29', 'max': 16, 'min': 3},
#       {'avg': 6, 'day': '2023-05-30', 'max': 14, 'min': 4},
#       {'avg': 6, 'day': '2023-05-31', 'max': 8, 'min': 4}],
#      'pm10': [{'avg': 46, 'day': '2023-05-25', 'max': 46, 'min': 46},
#       {'avg': 44, 'day': '2023-05-26', 'max': 46, 'min': 34},
#       {'avg': 36, 'day': '2023-05-27', 'max': 46, 'min': 24},
#       {'avg': 22, 'day': '2023-05-28', 'max': 28, 'min': 11},
#       {'avg': 20, 'day': '2023-05-29', 'max': 24, 'min': 15},
#       {'avg': 22, 'day': '2023-05-30', 'max': 24, 'min': 19},
#       {'avg': 17, 'day': '2023-05-31', 'max': 19, 'min': 15},
#       {'avg': 45, 'day': '2023-06-01', 'max': 58, 'min': 15}],
#      'pm25': [{'avg': 105, 'day': '2023-05-25', 'max': 138, 'min': 89},
#       {'avg': 103, 'day': '2023-05-26', 'max': 135, 'min': 89},
#       {'avg': 80, 'day': '2023-05-27', 'max': 89, 'min': 68},
#       {'avg': 46, 'day': '2023-05-28', 'max': 68, 'min': 21},
#       {'avg': 26, 'day': '2023-05-29', 'max': 29, 'min': 21},
#       {'avg': 32, 'day': '2023-05-30', 'max': 36, 'min': 26},
#       {'avg': 35, 'day': '2023-05-31', 'max': 42, 'min': 30},
#       {'avg': 103, 'day': '2023-06-01', 'max': 138, 'min': 30}]}},
#    'debug': {'sync': '2023-05-27T01:14:55+09:00'}}},
#  'taoyuan-city': {'status': 'ok',
#   'data': {'aqi': 38,
#    'idx': 13051,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [25.02726, 121.309392],
#     'name': 'North/CPC Taoyuan Refinery F1, Taiwan',
#     'url': 'https://aqicn.org/city/taiwan/north/cpc-taoyuan-refinery-f1',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 5.3},
#     'dew': {'v': 24},
#     'h': {'v': 71},
#     'o3': {'v': 24.1},
#     'p': {'v': 1011},
#     'pm10': {'v': 26},
#     'pm25': {'v': 38},
#     'so2': {'v': 10.2},
#     't': {'v': 27},
#     'w': {'v': 2},
#     'wg': {'v': 17.1}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 4,
#        'day': '2023-05-24',
#        'max': 26,
#        'min': 1},
#       {'avg': 6, 'day': '2023-05-25', 'max': 28, 'min': 1},
#       {'avg': 10, 'day': '2023-05-26', 'max': 33, 'min': 1},
#       {'avg': 13, 'day': '2023-05-27', 'max': 34, 'min': 3},
#       {'avg': 9, 'day': '2023-05-28', 'max': 21, 'min': 6},
#       {'avg': 6, 'day': '2023-05-29', 'max': 12, 'min': 4},
#       {'avg': 5, 'day': '2023-05-30', 'max': 11, 'min': 4},
#       {'avg': 5, 'day': '2023-05-31', 'max': 6, 'min': 4}],
#      'pm10': [{'avg': 46, 'day': '2023-05-25', 'max': 46, 'min': 46},
#       {'avg': 45, 'day': '2023-05-26', 'max': 46, 'min': 40},
#       {'avg': 38, 'day': '2023-05-27', 'max': 46, 'min': 30},
#       {'avg': 21, 'day': '2023-05-28', 'max': 30, 'min': 14},
#       {'avg': 24, 'day': '2023-05-29', 'max': 30, 'min': 19},
#       {'avg': 31, 'day': '2023-05-30', 'max': 37, 'min': 30},
#       {'avg': 21, 'day': '2023-05-31', 'max': 30, 'min': 19},
#       {'avg': 49, 'day': '2023-06-01', 'max': 58, 'min': 19}],
#      'pm25': [{'avg': 104, 'day': '2023-05-25', 'max': 138, 'min': 89},
#       {'avg': 97, 'day': '2023-05-26', 'max': 113, 'min': 89},
#       {'avg': 80, 'day': '2023-05-27', 'max': 89, 'min': 68},
#       {'avg': 47, 'day': '2023-05-28', 'max': 68, 'min': 21},
#       {'avg': 34, 'day': '2023-05-29', 'max': 40, 'min': 23},
#       {'avg': 42, 'day': '2023-05-30', 'max': 56, 'min': 30},
#       {'avg': 41, 'day': '2023-05-31', 'max': 61, 'min': 33},
#       {'avg': 104, 'day': '2023-06-01', 'max': 138, 'min': 33}]}},
#    'debug': {'sync': '2023-05-27T00:55:09+09:00'}}},
#  'Keelung': {'status': 'ok',
#   'data': {'aqi': 63,
#    'idx': 13011,
#    'attributions': [{'url': 'http://www.epa.gov.tw/',
#      'name': 'TAQM - Taiwan Environmental Protection Agency (行政院環保署－空氣品質監測網)',
#      'logo': 'Taiwan-EPA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [25.151481, 121.738251],
#     'name': 'North/Taipower Hsiehhe, Taiwan',
#     'url': 'https://aqicn.org/city/taiwan/north/taipower-hsiehhe',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'dew': {'v': 22},
#     'h': {'v': 74},
#     'no2': {'v': 4.7},
#     'p': {'v': 1012.6},
#     'pm10': {'v': 40},
#     'pm25': {'v': 63},
#     'so2': {'v': 2.3},
#     't': {'v': 26.8},
#     'w': {'v': 0.6},
#     'wg': {'v': 11.3}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 18,
#        'day': '2023-05-24',
#        'max': 26,
#        'min': 11},
#       {'avg': 17, 'day': '2023-05-25', 'max': 30, 'min': 8},
#       {'avg': 17, 'day': '2023-05-26', 'max': 29, 'min': 11},
#       {'avg': 18, 'day': '2023-05-27', 'max': 22, 'min': 17},
#       {'avg': 13, 'day': '2023-05-28', 'max': 17, 'min': 9},
#       {'avg': 8, 'day': '2023-05-29', 'max': 10, 'min': 6},
#       {'avg': 6, 'day': '2023-05-30', 'max': 8, 'min': 4},
#       {'avg': 6, 'day': '2023-05-31', 'max': 7, 'min': 6}],
#      'pm10': [{'avg': 49, 'day': '2023-05-24', 'max': 57, 'min': 31},
#       {'avg': 47, 'day': '2023-05-25', 'max': 57, 'min': 46},
#       {'avg': 46, 'day': '2023-05-26', 'max': 46, 'min': 46},
#       {'avg': 44, 'day': '2023-05-27', 'max': 46, 'min': 33},
#       {'avg': 24, 'day': '2023-05-28', 'max': 28, 'min': 19},
#       {'avg': 35, 'day': '2023-05-29', 'max': 46, 'min': 28},
#       {'avg': 44, 'day': '2023-05-30', 'max': 46, 'min': 44},
#       {'avg': 31, 'day': '2023-05-31', 'max': 44, 'min': 28},
#       {'avg': 48, 'day': '2023-06-01', 'max': 58, 'min': 28}],
#      'pm25': [{'avg': 77, 'day': '2023-05-24', 'max': 89, 'min': 68},
#       {'avg': 101, 'day': '2023-05-25', 'max': 138, 'min': 89},
#       {'avg': 83, 'day': '2023-05-26', 'max': 89, 'min': 69},
#       {'avg': 69, 'day': '2023-05-27', 'max': 71, 'min': 68},
#       {'avg': 26, 'day': '2023-05-28', 'max': 68, 'min': 21},
#       {'avg': 25, 'day': '2023-05-29', 'max': 30, 'min': 22},
#       {'avg': 40, 'day': '2023-05-30', 'max': 44, 'min': 30},
#       {'avg': 37, 'day': '2023-05-31', 'max': 45, 'min': 30},
#       {'avg': 77, 'day': '2023-06-01', 'max': 96, 'min': 30}]}},
#    'debug': {'sync': '2023-05-27T00:38:08+09:00'}}},
#  'Hong Kong': {'status': 'ok',
#   'data': {'aqi': 63,
#    'idx': 2571,
#    'attributions': [{'url': 'https://waqi.info/',
#      'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [22.2796569, 114.1719873],
#     'name': 'Central, HongKong (中環)',
#     'url': 'https://aqicn.org/city/hongkong/central',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'co': {'v': 1.6},
#     'h': {'v': 86},
#     'no2': {'v': 14.4},
#     'o3': {'v': 13.1},
#     'p': {'v': 1011.6},
#     'pm10': {'v': 20},
#     'pm25': {'v': 63},
#     'so2': {'v': 1.6},
#     't': {'v': 28.3},
#     'uvi': {'v': 0.16666666666666666},
#     'w': {'v': 0.3},
#     'wg': {'v': 1.6}},
#    'time': {'s': '2023-05-26 23:00:00',
#     'tz': '+08:00',
#     'v': 1685142000,
#     'iso': '2023-05-26T23:00:00+08:00'},
#    'forecast': {'daily': {'o3': [{'avg': 19,
#        'day': '2023-05-24',
#        'max': 23,
#        'min': 18},
#       {'avg': 9, 'day': '2023-05-25', 'max': 17, 'min': 7},
#       {'avg': 8, 'day': '2023-05-26', 'max': 14, 'min': 7},
#       {'avg': 13, 'day': '2023-05-27', 'max': 20, 'min': 10},
#       {'avg': 19, 'day': '2023-05-28', 'max': 27, 'min': 14},
#       {'avg': 19, 'day': '2023-05-29', 'max': 51, 'min': 7},
#       {'avg': 9, 'day': '2023-05-30', 'max': 44, 'min': 2},
#       {'avg': 3, 'day': '2023-05-31', 'max': 5, 'min': 1}],
#      'pm10': [{'avg': 29, 'day': '2023-05-25', 'max': 46, 'min': 22},
#       {'avg': 21, 'day': '2023-05-26', 'max': 28, 'min': 19},
#       {'avg': 42, 'day': '2023-05-27', 'max': 46, 'min': 19},
#       {'avg': 45, 'day': '2023-05-28', 'max': 46, 'min': 38},
#       {'avg': 55, 'day': '2023-05-29', 'max': 71, 'min': 46},
# ...
#     't': {'v': 14.91},
#     'w': {'v': 43.6},
#     'wd': {'v': 355.63},
#     'wg': {'v': 10.8}},
#    'time': {'tz': '+02:00', 'v': 0},
#    'forecast': {'daily': {'o3': [{'avg': 4,
#        'day': '2023-05-24',
#        'max': 18,
#        'min': 1},
#       {'avg': 9, 'day': '2023-05-25', 'max': 15, 'min': 4},
#       {'avg': 6, 'day': '2023-05-26', 'max': 14, 'min': 1},
#       {'avg': 4, 'day': '2023-05-27', 'max': 12, 'min': 1},
#       {'avg': 7, 'day': '2023-05-28', 'max': 14, 'min': 3},
#       {'avg': 4, 'day': '2023-05-29', 'max': 12, 'min': 1},
#       {'avg': 4, 'day': '2023-05-30', 'max': 15, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 70, 'day': '2023-05-24', 'max': 119, 'min': 24},
#       {'avg': 36, 'day': '2023-05-25', 'max': 51, 'min': 13},
#       {'avg': 47, 'day': '2023-05-26', 'max': 74, 'min': 21},
#       {'avg': 36, 'day': '2023-05-27', 'max': 71, 'min': 12},
#       {'avg': 15, 'day': '2023-05-28', 'max': 54, 'min': 9},
#       {'avg': 59, 'day': '2023-05-29', 'max': 126, 'min': 8},
#       {'avg': 47, 'day': '2023-05-30', 'max': 130, 'min': 14},
#       {'avg': 75, 'day': '2023-05-31', 'max': 75, 'min': 41}],
#      'pm25': [{'avg': 159, 'day': '2023-05-24', 'max': 206, 'min': 63},
#       {'avg': 88, 'day': '2023-05-25', 'max': 113, 'min': 35},
#       {'avg': 100, 'day': '2023-05-26', 'max': 163, 'min': 43},
#       {'avg': 85, 'day': '2023-05-27', 'max': 160, 'min': 22},
#       {'avg': 49, 'day': '2023-05-28', 'max': 144, 'min': 31},
#       {'avg': 124, 'day': '2023-05-29', 'max': 217, 'min': 14},
#       {'avg': 109, 'day': '2023-05-30', 'max': 227, 'min': 46},
#       {'avg': 170, 'day': '2023-05-31', 'max': 170, 'min': 110}]}},
#    'debug': {'sync': '2023-05-27T01:46:53+09:00'}}},
#  'benoni': {'status': 'ok',
#   'data': {'aqi': 154,
#    'idx': 11410,
#    'attributions': [{'url': 'https://saaqis.environment.gov.za',
#      'name': 'South African Air Quality Information System - SAAQIS',
#      'logo': 'SouthAfrica-DEA.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [-26.270361, 28.416005],
#     'name': 'Springs-NAQI, City  of  Ekurhuleni, South Africa',
#     'url': 'https://aqicn.org/city/south-africa/ekurhuleni-metro/springs',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'h': {'v': 65.2},
#     'no2': {'v': 16.9},
#     'p': {'v': 1014.7},
#     'pm10': {'v': 75},
#     'pm25': {'v': 154},
#     'so2': {'v': 10.6},
#     't': {'v': 14.1},
#     'w': {'v': 1.2},
#     'wg': {'v': 0.7}},
#    'time': {'s': '2023-05-26 17:00:00',
#     'tz': '+02:00',
#     'v': 1685120400,
#     'iso': '2023-05-26T17:00:00+02:00'},
#    'forecast': {'daily': {'o3': [{'avg': 5,
#        'day': '2023-05-24',
#        'max': 33,
#        'min': 1},
#       {'avg': 7, 'day': '2023-05-25', 'max': 18, 'min': 1},
#       {'avg': 7, 'day': '2023-05-26', 'max': 27, 'min': 2},
#       {'avg': 6, 'day': '2023-05-27', 'max': 13, 'min': 5},
#       {'avg': 7, 'day': '2023-05-28', 'max': 19, 'min': 5},
#       {'avg': 6, 'day': '2023-05-29', 'max': 19, 'min': 5},
#       {'avg': 6, 'day': '2023-05-30', 'max': 12, 'min': 4},
#       {'avg': 4, 'day': '2023-05-31', 'max': 5, 'min': 4}],
#      'pm10': [{'avg': 145, 'day': '2023-05-24', 'max': 310, 'min': 43},
#       {'avg': 63, 'day': '2023-05-25', 'max': 150, 'min': 24},
#       {'avg': 96, 'day': '2023-05-26', 'max': 191, 'min': 24},
#       {'avg': 31, 'day': '2023-05-27', 'max': 157, 'min': 9},
#       {'avg': 27, 'day': '2023-05-28', 'max': 38, 'min': 9},
#       {'avg': 45, 'day': '2023-05-29', 'max': 64, 'min': 18},
#       {'avg': 21, 'day': '2023-05-30', 'max': 41, 'min': 10},
#       {'avg': 13, 'day': '2023-05-31', 'max': 13, 'min': 8}],
#      'pm25': [{'avg': 218, 'day': '2023-05-24', 'max': 362, 'min': 80},
#       {'avg': 110, 'day': '2023-05-25', 'max': 236, 'min': 54},
#       {'avg': 151, 'day': '2023-05-26', 'max': 290, 'min': 51},
#       {'avg': 60, 'day': '2023-05-27', 'max': 242, 'min': 18},
#       {'avg': 51, 'day': '2023-05-28', 'max': 65, 'min': 19},
#       {'avg': 87, 'day': '2023-05-29', 'max': 135, 'min': 38},
#       {'avg': 45, 'day': '2023-05-30', 'max': 80, 'min': 18},
#       {'avg': 25, 'day': '2023-05-31', 'max': 25, 'min': 15}]}},
#    'debug': {'sync': '2023-05-27T01:46:52+09:00'}}},
#  'Addis Ababa': {'status': 'ok',
#   'data': {'aqi': 50,
#    'idx': 9059,
#    'attributions': [{'url': 'http://worldweather.wmo.int',
#      'name': 'World Meteorological Organization - surface synoptic observations (WMO-SYNOP)'},
#     {'url': 'http://et.usembassy.gov/',
#      'name': 'Addis Ababa Air Quality Monitor - US Embassy',
#      'logo': 'US-StateDepartment.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [9.058498, 38.761642],
#     'name': 'Addis Ababa US Embassy, Ethiopia',
#     'url': 'https://aqicn.org/city/ethiopia/addis-ababa/us-embassy',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'dew': {'v': 10},
#     'h': {'v': 55},
#     'p': {'v': 1017},
#     'pm25': {'v': 50},
#     't': {'v': 19},
#     'w': {'v': 4.1}},
#    'time': {'s': '2023-05-26 19:00:00',
#     'tz': '+03:00',
#     'v': 1685127600,
#     'iso': '2023-05-26T19:00:00+03:00'},
#    'forecast': {'daily': {'o3': [{'avg': 10,
#        'day': '2023-05-24',
#        'max': 46,
#        'min': 1},
#       {'avg': 10, 'day': '2023-05-25', 'max': 49, 'min': 1},
#       {'avg': 9, 'day': '2023-05-26', 'max': 45, 'min': 1},
#       {'avg': 7, 'day': '2023-05-27', 'max': 29, 'min': 1},
#       {'avg': 4, 'day': '2023-05-28', 'max': 14, 'min': 1},
#       {'avg': 8, 'day': '2023-05-29', 'max': 43, 'min': 1},
#       {'avg': 11, 'day': '2023-05-30', 'max': 63, 'min': 1},
#       {'avg': 1, 'day': '2023-05-31', 'max': 1, 'min': 1}],
#      'pm10': [{'avg': 319, 'day': '2023-05-24', 'max': 491, 'min': 56},
#       {'avg': 281, 'day': '2023-05-25', 'max': 500, 'min': 27},
#       {'avg': 215, 'day': '2023-05-26', 'max': 500, 'min': 34},
#       {'avg': 106, 'day': '2023-05-27', 'max': 220, 'min': 20},
#       {'avg': 94, 'day': '2023-05-28', 'max': 186, 'min': 18},
#       {'avg': 266, 'day': '2023-05-29', 'max': 434, 'min': 41},
#       {'avg': 229, 'day': '2023-05-30', 'max': 441, 'min': 35},
#       {'avg': 193, 'day': '2023-05-31', 'max': 219, 'min': 144}],
#      'pm25': [{'avg': 353, 'day': '2023-05-24', 'max': 485, 'min': 89},
#       {'avg': 333, 'day': '2023-05-25', 'max': 500, 'min': 55},
#       {'avg': 263, 'day': '2023-05-26', 'max': 500, 'min': 66},
#       {'avg': 184, 'day': '2023-05-27', 'max': 354, 'min': 47},
#       {'avg': 178, 'day': '2023-05-28', 'max': 316, 'min': 34},
#       {'avg': 338, 'day': '2023-05-29', 'max': 460, 'min': 69},
#       {'avg': 304, 'day': '2023-05-30', 'max': 466, 'min': 66},
#       {'avg': 323, 'day': '2023-05-31', 'max': 351, 'min': 244}]}},
#    'debug': {'sync': '2023-05-27T01:37:06+09:00'}}},
#  'Nairobi': {'status': 'ok',
#   'data': {'aqi': 94,
#    'idx': 13818,
#    'attributions': [{'url': 'https://ke.usembassy.gov/',
#      'name': 'Nairobi Air Quality Monitor - US EPA',
#      'logo': 'US-StateDepartment.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [-1.23437, 36.81732],
#     'name': 'Nairobi US Embassy, Kenya',
#     'url': 'https://aqicn.org/city/kenya/nairobi/us-embassy',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'dew': {'v': 6},
#     'h': {'v': 27},
#     'p': {'v': 1018},
#     'pm25': {'v': 94},
#     't': {'v': 26},
#     'w': {'v': 6.1}},
#    'time': {'s': '2023-02-21 18:00:00',
#     'tz': '+03:00',
#     'v': 1677002400,
#     'iso': '2023-02-21T18:00:00+03:00'},
#    'forecast': {'daily': {'o3': [{'avg': 7,
#        'day': '2023-02-19',
#        'max': 8,
#        'min': 5},
#       {'avg': 10, 'day': '2023-02-20', 'max': 14, 'min': 6},
#       {'avg': 11, 'day': '2023-02-21', 'max': 17, 'min': 7},
#       {'avg': 10, 'day': '2023-02-22', 'max': 15, 'min': 6},
#       {'avg': 9, 'day': '2023-02-23', 'max': 14, 'min': 5},
#       {'avg': 8, 'day': '2023-02-24', 'max': 12, 'min': 4},
#       {'avg': 7, 'day': '2023-02-25', 'max': 10, 'min': 4},
#       {'avg': 6, 'day': '2023-02-26', 'max': 6, 'min': 5}],
#      'pm10': [{'avg': 19, 'day': '2023-02-19', 'max': 33, 'min': 7},
#       {'avg': 37, 'day': '2023-02-20', 'max': 56, 'min': 17},
#       {'avg': 52, 'day': '2023-02-21', 'max': 80, 'min': 26},
#       {'avg': 45, 'day': '2023-02-22', 'max': 69, 'min': 25},
#       {'avg': 44, 'day': '2023-02-23', 'max': 69, 'min': 21},
#       {'avg': 34, 'day': '2023-02-24', 'max': 52, 'min': 20},
#       {'avg': 21, 'day': '2023-02-25', 'max': 34, 'min': 11},
#       {'avg': 12, 'day': '2023-02-26', 'max': 15, 'min': 12}],
#      'pm25': [{'avg': 35, 'day': '2023-02-19', 'max': 59, 'min': 13},
#       {'avg': 67, 'day': '2023-02-20', 'max': 90, 'min': 32},
#       {'avg': 93, 'day': '2023-02-21', 'max': 153, 'min': 55},
#       {'avg': 77, 'day': '2023-02-22', 'max': 121, 'min': 50},
#       {'avg': 75, 'day': '2023-02-23', 'max': 124, 'min': 43},
#       {'avg': 59, 'day': '2023-02-24', 'max': 78, 'min': 38},
#       {'avg': 37, 'day': '2023-02-25', 'max': 57, 'min': 21},
#       {'avg': 22, 'day': '2023-02-26', 'max': 25, 'min': 21}]}},
#    'debug': {'sync': '2023-02-22T00:37:10+09:00'}}},
#  'Kampala': {'status': 'ok',
#   'data': {'aqi': 87,
#    'idx': 9470,
#    'attributions': [{'url': 'https://ug.usembassy.gov/',
#      'name': 'Kampala Air Quality Monitor - US Embassy',
#      'logo': 'US-StateDepartment.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [0.300225, 32.591553],
#     'name': 'Kampala US Embassy, Uganda',
#     'url': 'https://aqicn.org/city/uganda/kampala/us-embassy',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'dew': {'v': 20},
#     'h': {'v': 73},
#     'p': {'v': 1016},
#     'pm25': {'v': 87},
#     't': {'v': 25},
#     'w': {'v': 3}},
#    'time': {'s': '2023-05-26 19:00:00',
#     'tz': '+03:00',
#     'v': 1685127600,
#     'iso': '2023-05-26T19:00:00+03:00'},
#    'forecast': {'daily': {'o3': [{'avg': 5,
#        'day': '2023-05-24',
#        'max': 11,
#        'min': 1},
#       {'avg': 6, 'day': '2023-05-25', 'max': 11, 'min': 1},
#       {'avg': 4, 'day': '2023-05-26', 'max': 9, 'min': 1},
#       {'avg': 5, 'day': '2023-05-27', 'max': 11, 'min': 1},
#       {'avg': 6, 'day': '2023-05-28', 'max': 10, 'min': 4},
#       {'avg': 5, 'day': '2023-05-29', 'max': 7, 'min': 2},
#       {'avg': 6, 'day': '2023-05-30', 'max': 13, 'min': 1},
#       {'avg': 4, 'day': '2023-05-31', 'max': 4, 'min': 2}],
#      'pm10': [{'avg': 83, 'day': '2023-05-24', 'max': 333, 'min': 14},
#       {'avg': 95, 'day': '2023-05-25', 'max': 275, 'min': 12},
#       {'avg': 70, 'day': '2023-05-26', 'max': 131, 'min': 8},
#       {'avg': 66, 'day': '2023-05-27', 'max': 155, 'min': 7},
#       {'avg': 37, 'day': '2023-05-28', 'max': 59, 'min': 9},
#       {'avg': 49, 'day': '2023-05-29', 'max': 110, 'min': 7},
#       {'avg': 67, 'day': '2023-05-30', 'max': 109, 'min': 12},
#       {'avg': 94, 'day': '2023-05-31', 'max': 94, 'min': 70}],
#      'pm25': [{'avg': 146, 'day': '2023-05-24', 'max': 419, 'min': 21},
#       {'avg': 157, 'day': '2023-05-25', 'max': 365, 'min': 18},
#       {'avg': 125, 'day': '2023-05-26', 'max': 198, 'min': 12},
#       {'avg': 115, 'day': '2023-05-27', 'max': 265, 'min': 11},
#       {'avg': 71, 'day': '2023-05-28', 'max': 114, 'min': 13},
#       {'avg': 93, 'day': '2023-05-29', 'max': 180, 'min': 8},
#       {'avg': 128, 'day': '2023-05-30', 'max': 179, 'min': 18},
#       {'avg': 166, 'day': '2023-05-31', 'max': 166, 'min': 151}]}},
#    'debug': {'sync': '2023-05-27T01:37:09+09:00'}}},
#  'Algiers': {'status': 'ok',
#   'data': {'aqi': 57,
#    'idx': 11732,
#    'attributions': [{'url': 'https://dz.usembassy.gov/',
#      'name': 'Algiers Air Quality Monitor - US EPA',
#      'logo': 'US-StateDepartment.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [36.7558, 3.039114],
#     'name': 'Algiers US Embassy, Algeria',
#     'url': 'https://aqicn.org/city/algeria/algiers/us-embassy',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'dew': {'v': 16},
#     'h': {'v': 57},
#     'p': {'v': 1016},
#     'pm25': {'v': 57},
#     't': {'v': 25},
#     'w': {'v': 6.1}},
#    'time': {'s': '2023-05-26 17:00:00',
#     'tz': '+01:00',
#     'v': 1685120400,
#     'iso': '2023-05-26T17:00:00+01:00'},
#    'forecast': {'daily': {'o3': [{'avg': 38,
#        'day': '2023-05-24',
#        'max': 45,
#        'min': 30},
#       {'avg': 35, 'day': '2023-05-25', 'max': 47, 'min': 27},
#       {'avg': 31, 'day': '2023-05-26', 'max': 47, 'min': 14},
#       {'avg': 24, 'day': '2023-05-27', 'max': 41, 'min': 16},
#       {'avg': 31, 'day': '2023-05-28', 'max': 43, 'min': 22},
#       {'avg': 35, 'day': '2023-05-29', 'max': 44, 'min': 24},
#       {'avg': 31, 'day': '2023-05-30', 'max': 34, 'min': 31}],
#      'pm10': [{'avg': 12, 'day': '2023-05-24', 'max': 14, 'min': 10},
#       {'avg': 15, 'day': '2023-05-25', 'max': 25, 'min': 7},
#       {'avg': 26, 'day': '2023-05-26', 'max': 31, 'min': 21},
#       {'avg': 24, 'day': '2023-05-27', 'max': 34, 'min': 13},
#       {'avg': 19, 'day': '2023-05-28', 'max': 31, 'min': 13},
#       {'avg': 15, 'day': '2023-05-29', 'max': 19, 'min': 11},
#       {'avg': 17, 'day': '2023-05-30', 'max': 17, 'min': 15}],
#      'pm25': [{'avg': 34, 'day': '2023-05-24', 'max': 40, 'min': 28},
#       {'avg': 44, 'day': '2023-05-25', 'max': 65, 'min': 26},
#       {'avg': 60, 'day': '2023-05-26', 'max': 78, 'min': 43},
#       {'avg': 54, 'day': '2023-05-27', 'max': 60, 'min': 48},
#       {'avg': 50, 'day': '2023-05-28', 'max': 57, 'min': 43},
#       {'avg': 46, 'day': '2023-05-29', 'max': 53, 'min': 29},
#       {'avg': 48, 'day': '2023-05-30', 'max': 51, 'min': 47}]}},
#    'debug': {'sync': '2023-05-27T01:37:08+09:00'}}},
#  'Bamako': {'status': 'ok',
#   'data': {'aqi': 117,
#    'idx': 12640,
#    'attributions': [{'url': 'https://ml.usembassy.gov/',
#      'name': 'Bamako Air Quality Monitor - US EPA',
#      'logo': 'US-StateDepartment.png'},
#     {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#    'city': {'geo': [12.632524, -8.036911],
#     'name': 'Bamako US Embassy, Mali',
#     'url': 'https://aqicn.org/city/mlbamako/us-embassy',
#     'location': ''},
#    'dominentpol': 'pm25',
#    'iaqi': {'dew': {'v': 14},
#     'h': {'v': 25.5},
#     'p': {'v': 1010},
#     'pm25': {'v': 117},
#     't': {'v': 36.5},
#     'w': {'v': 6.1},
#     'wg': {'v': 8.7}},
#    'time': {'s': '2023-05-04 19:00:00',
#     'tz': '+00:00',
#     'v': 1683226800,
#     'iso': '2023-05-04T19:00:00Z'},
#    'forecast': {'daily': {'o3': [{'avg': 5,
#        'day': '2023-05-02',
#        'max': 8,
#        'min': 1},
#       {'avg': 4, 'day': '2023-05-03', 'max': 8, 'min': 2},
#       {'avg': 4, 'day': '2023-05-04', 'max': 10, 'min': 2},
#       {'avg': 4, 'day': '2023-05-05', 'max': 7, 'min': 2},
#       {'avg': 4, 'day': '2023-05-06', 'max': 5, 'min': 2},
#       {'avg': 4, 'day': '2023-05-07', 'max': 6, 'min': 2},
#       {'avg': 3, 'day': '2023-05-08', 'max': 8, 'min': 2},
#       {'avg': 2, 'day': '2023-05-09', 'max': 2, 'min': 2}],
#      'pm10': [{'avg': 36, 'day': '2023-05-02', 'max': 60, 'min': 12},
#       {'avg': 57, 'day': '2023-05-03', 'max': 70, 'min': 46},
#       {'avg': 52, 'day': '2023-05-04', 'max': 70, 'min': 36},
#       {'avg': 46, 'day': '2023-05-05', 'max': 76, 'min': 18},
#       {'avg': 21, 'day': '2023-05-06', 'max': 70, 'min': 7},
#       {'avg': 19, 'day': '2023-05-07', 'max': 30, 'min': 9},
#       {'avg': 20, 'day': '2023-05-08', 'max': 33, 'min': 11},
#       {'avg': 30, 'day': '2023-05-09', 'max': 30, 'min': 27}],
#      'pm25': [{'avg': 60, 'day': '2023-05-02', 'max': 117, 'min': 24},
#       {'avg': 71, 'day': '2023-05-03', 'max': 116, 'min': 55},
#       {'avg': 65, 'day': '2023-05-04', 'max': 96, 'min': 43},
#       {'avg': 68, 'day': '2023-05-05', 'max': 129, 'min': 21},
#       {'avg': 36, 'day': '2023-05-06', 'max': 113, 'min': 12},
#       {'avg': 44, 'day': '2023-05-07', 'max': 72, 'min': 25},
#       {'avg': 47, 'day': '2023-05-08', 'max': 74, 'min': 32},
#       {'avg': 64, 'day': '2023-05-09', 'max': 64, 'min': 58}]}},
#    'debug': {'sync': '2023-05-05T05:01:13+09:00'}}}}

# %%
# Check if we have at least 500 row of data
num_cities = len(data)
print(f"There are {num_cities} cities in the JSON file.")
# Out:
# There are 532 cities in the JSON file.

# %%
status_set = set()

for city in data:
    if 'status' in data[city]:  # ensure that the 'status' key exists
        status_set.add(data[city]['status'])

status_set
# Out:
# {'error', 'nope', 'ok'}

# %%
from collections import defaultdict

status_counts = defaultdict(int)  # initialize counter with 0 as default value for non-existing keys

for city_data in data.values():
    status_counts[city_data['status']] += 1

for status, count in status_counts.items():
    print(f"There are {count} cities with status '{status}'")
# Out:
# There are 497 cities with status 'ok'
# There are 31 cities with status 'error'
# There are 4 cities with status 'nope'

# %%
import datetime

# Date to check
check_date = datetime.datetime.strptime("2023-05-28", "%Y-%m-%d")

# Dictionary to hold the cleaned data
cleaned_data = {}

# Iterate through the cities in the data
for city_name, city_info in data.items():
    # Check status
    if city_info['status'] != 'ok':
        continue

    # Check if the 'daily' key exists
    if 'forecast' in city_info['data'] and 'daily' in city_info['data']['forecast']:
        forecast = city_info['data']['forecast']['daily']
        for pollutant in forecast:
            # If any forecast date is later than check_date, remove it
            forecast[pollutant] = [day for day in forecast[pollutant] if datetime.datetime.strptime(day['day'], "%Y-%m-%d") <= check_date]
    else:
        # If there's no 'daily' key, skip this city
        continue

    cleaned_data[city_name] = city_info

# Save the cleaned data to a new file
with open('aqi_data_ok_status.json', 'w') as f:
    json.dump(cleaned_data, f, indent=4)

# %%
#ok_status_data = {city: details for city, details in data.items() if details['status'] == 'ok'}

#with open('aqi_data_ok_status.json', 'w') as f:
    #json.dump(ok_status_data, f, indent=4)
